# %% [markdown]
# ## A.R.D.E 🔥🔥🔥

# %%
import pandas as pd

path = '../data/PS_2025.10.17_07.44.21.csv'

df = pd.read_csv(path, skiprows=292).set_index('rowid')
df
# Out:
# C:\Users\rayen\AppData\Local\Temp\ipykernel_21444\1685644211.py:5: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, skiprows=292).set_index('rowid')
#          pl_name hostname pl_letter    hd_name   hip_name         tic_id  \
# rowid
# 1       11 Com b   11 Com         b  HD 107383  HIP 60202   TIC 72437047
# 2       11 Com b   11 Com         b  HD 107383  HIP 60202   TIC 72437047
# 3       11 Com b   11 Com         b  HD 107383  HIP 60202   TIC 72437047
# 4       11 UMi b   11 UMi         b  HD 136726  HIP 74793  TIC 230061010
# 5       11 UMi b   11 UMi         b  HD 136726  HIP 74793  TIC 230061010
# ...          ...      ...       ...        ...        ...            ...
# 38969  ups And d  ups And         d    HD 9826   HIP 7513  TIC 189576919
# 38970  ups Leo b  ups Leo         b        NaN        NaN   TIC 49430557
# 38971   xi Aql b   xi Aql         b  HD 188310  HIP 97938  TIC 375464367
# ...

# %%
for index in df.dtypes:
    print(index)
# Out:
# object
# object
# object
# object
# object
# object
# object
# object
# int64
# int64
# int64
# int64
# int64
# object
# int64
# object
# object
# object
# object
# object
# object
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# object
# int64
# object
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# ...
